# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
data_amp = pd.read_csv('MPA_sub_frin_2004-2023_annuel.csv')
data_all = pd.read_csv('substrat_frin_1987-2023-annuel.csv')

# %%
# rename date column
data_amp.rename(columns={'YearSeason': 'Date'}, inplace=True)
data_all.rename(columns={'YearSeason': 'Date'}, inplace=True)

# %%
# convert date columns to the same format
data_amp['Date'] = pd.to_datetime(data_amp['Date']).dt.to_period('M').dt.to_timestamp()
data_all['Date'] = pd.to_datetime(data_all['Date']).dt.to_period('M').dt.to_timestamp()

# %%
# merge dataframes
data = pd.merge(data_amp, data_all, on='Date', how='outer')

# %%
data.set_index('Date', inplace=True)
data.index = pd.to_datetime(data.index)

# %%
# replace all _x named columns with _amp, _y with _all
data.columns = data.columns.str.replace('_x', '_amp')
data.columns = data.columns.str.replace('_y', '_all')

# %%
data
# Out:
#             Algae_amp  Dead Coral  Live Coral_amp       Mud  Others_amp  \
# Date
# 2004-10-01   0.013767    0.000000        0.287233  0.000000    0.000000
# 2005-03-01   0.060133    0.013333        0.207333  0.000000    0.020133
# 2005-10-01   0.077000    0.055667        0.271667  0.000000    0.006667
# 2006-03-01   0.140000    0.060000        0.273333  0.000000    0.006667
# 2006-10-01   0.240000    0.000000        0.173333  0.266667    0.000000
# ...               ...         ...             ...       ...         ...
# 2019-12-01        NaN         NaN             NaN       NaN         NaN
# 2020-12-01        NaN         NaN             NaN       NaN         NaN
# 2021-11-01        NaN         NaN             NaN       NaN         NaN
# 2022-01-01        NaN         NaN             NaN       NaN         NaN
# 2023-10-01        NaN         NaN             NaN       NaN         NaN
#
#             Pavement_amp  Rubble_amp  Sand_amp  Turf_amp  Algae_all  \
# Date
# 2004-10-01      0.401833    0.060000  0.237167       0.0        NaN
# 2005-03-01      0.496733    0.081233  0.121100       0.0        NaN
# 2005-10-01      0.194000    0.041667  0.352000       0.0        NaN
# 2006-03-01      0.186667    0.246667  0.086667       0.0        NaN
# 2006-10-01      0.060000    0.106667  0.153333       0.0        NaN
# ...                  ...         ...       ...       ...        ...
# 2019-12-01           NaN         NaN       NaN       NaN      0.304
# 2020-12-01           NaN         NaN       NaN       NaN      0.284
# 2021-11-01           NaN         NaN       NaN       NaN      0.220
# 2022-01-01           NaN         NaN       NaN       NaN      0.324
# 2023-10-01           NaN         NaN       NaN       NaN      0.356
#
#             Calcified Algae  Live Coral_all  Others_all  Pavement_all  \
# Date
# 2004-10-01              NaN             NaN         NaN           NaN
# 2005-03-01              NaN             NaN         NaN           NaN
# 2005-10-01              NaN             NaN         NaN           NaN
# 2006-03-01              NaN             NaN         NaN           NaN
# 2006-10-01              NaN             NaN         NaN           NaN
# ...                     ...             ...         ...           ...
# 2019-12-01            0.004           0.060       0.004         0.076
# 2020-12-01            0.000           0.060       0.016         0.084
# 2021-11-01            0.004           0.052       0.004         0.012
# 2022-01-01            0.000           0.076       0.000         0.016
# 2023-10-01            0.008           0.092       0.000         0.008
#
#             Rubble_all  Sand_all  Turf_all
# Date
# 2004-10-01         NaN       NaN       NaN
# 2005-03-01         NaN       NaN       NaN
# 2005-10-01         NaN       NaN       NaN
# 2006-03-01         NaN       NaN       NaN
# 2006-10-01         NaN       NaN       NaN
# ...                ...       ...       ...
# 2019-12-01       0.092     0.416     0.044
# 2020-12-01       0.112     0.392     0.052
# 2021-11-01       0.044     0.464     0.200
# 2022-01-01       0.072     0.388     0.124
# 2023-10-01       0.052     0.424     0.060
#
# [61 rows x 17 columns]

# %%
set_columns = ['Algae_amp', 'Algae_all']

# plot set of columns
plt.figure()
plt.title('Algae')
plt.xlabel('Date')
plt.ylabel('Algae')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
data.columns
# Out:
# Index(['Algae_amp', 'Dead Coral', 'Live Coral_amp', 'Mud', 'Others_amp',
#        'Pavement_amp', 'Rubble_amp', 'Sand_amp', 'Turf_amp', 'Algae_all',
#        'Calcified Algae', 'Live Coral_all', 'Others_all', 'Pavement_all',
#        'Rubble_all', 'Sand_all', 'Turf_all'],
#       dtype='object')

# %%
set_columns = ['Calcified Algae']

# plot set of columns
plt.figure()
plt.title('Calcified Algae')
plt.xlabel('Date')
plt.ylabel('Calcified Algae')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
set_columns = ['Live Coral_amp', 'Live Coral_all']

# plot set of columns
plt.figure()
plt.title('Live Coral')
plt.xlabel('Date')
plt.ylabel('Live Coral')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# for sand
set_columns = ['Sand_amp', 'Sand_all']

# plot set of columns
plt.figure()
plt.title('Sand')
plt.xlabel('Date')
plt.ylabel('Sand')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# for rubble
set_columns = ['Rubble_amp', 'Rubble_all']

# plot set of columns
plt.figure()
plt.title('Rubble')
plt.xlabel('Date')
plt.ylabel('Rubble')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# for pavement
set_columns = ['Pavement_amp', 'Pavement_all']

# plot set of columns
plt.figure()
plt.title('Pavement')
plt.xlabel('Date')
plt.ylabel('Pavement')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# for turf
set_columns = ['Turf_amp', 'Turf_all']

# plot set of columns
plt.figure()
plt.title('Turf')
plt.xlabel('Date')
plt.ylabel('Turf')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# for Others
set_columns = ['Others_amp', 'Others_all']

# plot set of columns
plt.figure()
plt.title('Others')
plt.xlabel('Date')
plt.ylabel('Others')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# plot Dead Coral
set_columns = ['Dead Coral']

# plot set of columns
plt.figure()
plt.title('Dead Coral')
plt.xlabel('Date')
plt.ylabel('Dead Coral')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# add dead coral to turf amp and compare again the turf columns
data['Turf_amp'] = data['Turf_amp'] + data['Dead Coral']

# for turf
set_columns = ['Turf_amp', 'Turf_all']

# plot set of columns
plt.figure()
plt.title('Turf')
plt.xlabel('Date')
plt.ylabel('Turf')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
data_all.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# compute a mineral column adding sand, rubble and pavement for each dataset
data['Mineral_amp'] = data['Sand_amp'] + data['Rubble_amp'] + data['Pavement_amp']
data['Mineral_all'] = data['Sand_all'] + data['Rubble_all'] + data['Pavement_all']

# for mineral
set_columns = ['Mineral_amp', 'Mineral_all']

# plot set of columns
plt.figure()
plt.title('Mineral')
plt.xlabel('Date')
plt.ylabel('Mineral')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# %%
# create alt_death rate column for each dataset, equals to the difference between this year's live coral and last year's live coral, divided by last year's live coral
def compute_death_rate(column):
    death_rate = []
    death_rate.append(np.nan)
    for i in range(1, len(column)):
        if np.isnan(column[i-1]):
            death_rate.append(np.nan)
        else :
            death_rate.append(column[i-1] - column[i])
    return death_rate 

data['Alt_death_rate_amp'] = compute_death_rate(data['Live Coral_amp'])
data['Alt_death_rate_all'] = compute_death_rate(data['Live Coral_all'])

# for alt_death_rate
set_columns = ['Alt_death_rate_amp', 'Alt_death_rate_all']
# add column dead coral to alt death rate_amp
data['Alt_death_rate_amp'] = data['Alt_death_rate_amp'] + data['Dead Coral']

# plot set of columns
plt.figure()

plt.title('Alt_death_rate')
plt.xlabel('Date')
plt.ylabel('Alt_death_rate')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# bleaching events list
list_bleaching = ['1983-02', '1983-09', '1987-02', '1987-09','1991-02', '1991-09', '1994-02', '1994-09', '1998-02', '1998-09', '2002-02', '2002-09', '2003-02', '2003-09', '2007-02', '2007-09', '2016-02', '2016-09', '2019-02', '2019-09']

list_bleaching = pd.to_datetime(list_bleaching)

# add vertical lines for bleaching events
for i in list_bleaching:
    plt.axvline(x=i, color='r', linestyle='--')
# Out:
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if np.isnan(column[i-1]):
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   death_rate.append(column[i-1] - column[i])
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if np.isnan(column[i-1]):
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   death_rate.append(column[i-1] - column[i])

# %%
# compute the discrete derivative of the alt death rate and add it to the dataframe
data['Alt_death_rate_derivative_amp'] = data['Alt_death_rate_amp'].diff()
data['Alt_death_rate_derivative_all'] = data['Alt_death_rate_all'].diff()

# for alt_death_rate_derivative
set_columns = ['Alt_death_rate_derivative_amp', 'Alt_death_rate_derivative_all']

# plot set of columns
plt.figure()
plt.title('Alt_death_rate_derivative')
plt.xlabel('Date')
plt.ylabel('Alt_death_rate_derivative')
plt.plot(data[set_columns], label=set_columns)
plt.legend()

# add vertical lines for bleaching events
for i in list_bleaching:
    plt.axvline(x=i, color='r', linestyle='--')

# %%
data_amp.set_index('Date', inplace=True)
data_amp.index = pd.to_datetime(data_amp.index)

data_all.set_index('Date', inplace=True)
data_all.index = pd.to_datetime(data_all.index)

# %%
data_amp.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data_amp['Alt_death_rate_amp'] = compute_death_rate(data_amp['Live Coral'])
data_all['Alt_death_rate_all'] = compute_death_rate(data_all['Live Coral'])
# Out:
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if np.isnan(column[i-1]):
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   death_rate.append(column[i-1] - column[i])
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if np.isnan(column[i-1]):
# C:\Users\alexi\AppData\Local\Temp\ipykernel_198376\2319456587.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   death_rate.append(column[i-1] - column[i])

# %%
data_amp['Alt_death_rate_derivative_amp'] = data_amp['Alt_death_rate_amp'].diff()
data_all['Alt_death_rate_derivative_all'] = data_all['Alt_death_rate_all'].diff()

# %%
# correlation matrix
data_amp.corr()
# Out:
#                                   Algae  Dead Coral  Live Coral       Mud  \
# Algae                          1.000000    0.054141   -0.364322  0.146396
# Dead Coral                     0.054141    1.000000    0.594147 -0.157856
# Live Coral                    -0.364322    0.594147    1.000000 -0.143497
# Mud                            0.146396   -0.157856   -0.143497  1.000000
# Others                        -0.279946   -0.120206   -0.051269 -0.067443
# Pavement                      -0.126494   -0.417024   -0.420700 -0.170873
# Rubble                         0.313258    0.059226   -0.027726 -0.104407
# Sand                           0.040202   -0.122473   -0.208543 -0.601548
# Turf                          -0.504025   -0.298294   -0.105809  0.043087
# Alt_death_rate_amp             0.502835   -0.208724   -0.721272  0.079274
# Alt_death_rate_derivative_amp  0.324415    0.075817   -0.346897  0.064290
#
#                                  Others  Pavement    Rubble      Sand  \
# Algae                         -0.279946 -0.126494  0.313258  0.040202
# Dead Coral                    -0.120206 -0.417024  0.059226 -0.122473
# Live Coral                    -0.051269 -0.420700 -0.027726 -0.208543
# Mud                           -0.067443 -0.170873 -0.104407 -0.601548
# Others                         1.000000  0.362550 -0.303798  0.094640
# Pavement                       0.362550  1.000000 -0.272512  0.106445
# Rubble                        -0.303798 -0.272512  1.000000 -0.177477
# Sand                           0.094640  0.106445 -0.177477  1.000000
# Turf                          -0.033447 -0.229278 -0.187682 -0.221957
# Alt_death_rate_amp            -0.007757  0.251479  0.132283  0.083089
# Alt_death_rate_derivative_amp  0.042178  0.068043  0.145220 -0.007411
#
#                                    Turf  Alt_death_rate_amp  \
# Algae                         -0.504025            0.502835
# Dead Coral                    -0.298294           -0.208724
# Live Coral                    -0.105809           -0.721272
# Mud                            0.043087            0.079274
# Others                        -0.033447           -0.007757
# Pavement                      -0.229278            0.251479
# Rubble                        -0.187682            0.132283
# Sand                          -0.221957            0.083089
# Turf                           1.000000           -0.068813
# Alt_death_rate_amp            -0.068813            1.000000
# Alt_death_rate_derivative_amp -0.123928            0.831030
#
#                                Alt_death_rate_derivative_amp
# Algae                                               0.324415
# Dead Coral                                          0.075817
# Live Coral                                         -0.346897
# Mud                                                 0.064290
# Others                                              0.042178
# Pavement                                            0.068043
# Rubble                                              0.145220
# Sand                                               -0.007411
# Turf                                               -0.123928
# Alt_death_rate_amp                                  0.831030
# Alt_death_rate_derivative_amp                       1.000000

# %%
data_all.corr()
# Out:
#                                   Algae  Calcified Algae  Live Coral  \
# Algae                          1.000000        -0.187526   -0.149984
# Calcified Algae               -0.187526         1.000000    0.252932
# Live Coral                    -0.149984         0.252932    1.000000
# Others                         0.155941        -0.151682    0.038500
# Pavement                      -0.287105         0.047664   -0.417304
# Rubble                        -0.628911        -0.030266   -0.087667
# Sand                          -0.701031        -0.144127   -0.008292
# Turf                          -0.323845         0.177420    0.261736
# Alt_death_rate_all            -0.114715        -0.179786   -0.669549
# Alt_death_rate_derivative_all -0.153245        -0.101276   -0.327180
#
#                                  Others  Pavement    Rubble      Sand  \
# Algae                          0.155941 -0.287105 -0.628911 -0.701031
# Calcified Algae               -0.151682  0.047664 -0.030266 -0.144127
# Live Coral                     0.038500 -0.417304 -0.087667 -0.008292
# Others                         1.000000 -0.163524 -0.163561 -0.184249
# Pavement                      -0.163524  1.000000  0.343636  0.206776
# Rubble                        -0.163561  0.343636  1.000000  0.111336
# Sand                          -0.184249  0.206776  0.111336  1.000000
# Turf                           0.040540 -0.530852  0.054077 -0.029908
# Alt_death_rate_all            -0.175335  0.232733  0.258185  0.147644
# Alt_death_rate_derivative_all -0.162462  0.089691  0.181863  0.179051
#
#                                    Turf  Alt_death_rate_all  \
# Algae                         -0.323845           -0.114715
# Calcified Algae                0.177420           -0.179786
# Live Coral                     0.261736           -0.669549
# Others                         0.040540           -0.175335
# Pavement                      -0.530852            0.232733
# Rubble                         0.054077            0.258185
# Sand                          -0.029908            0.147644
# Turf                           1.000000           -0.023641
# Alt_death_rate_all            -0.023641            1.000000
# Alt_death_rate_derivative_all  0.024358            0.839333
#
#                                Alt_death_rate_derivative_all
# Algae                                              -0.153245
# Calcified Algae                                    -0.101276
# Live Coral                                         -0.327180
# Others                                             -0.162462
# Pavement                                            0.089691
# Rubble                                              0.181863
# Sand                                                0.179051
# Turf                                                0.024358
# Alt_death_rate_all                                  0.839333
# Alt_death_rate_derivative_all                       1.000000
