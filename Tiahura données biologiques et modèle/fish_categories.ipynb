# %%
import pandas as pd

# %%
data_1 = pd.read_excel('serieTiahura_Fish_83-2023.xlsx', sheet_name='données brutes')
# Out:
# c:\miniconda\envs\Python_update\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data_2 = pd.read_excel('AMP/MPA_data_fish.xlsx')

# %%
data_3 = pd.read_excel('ATPP/DataATPPfish20230418.xlsx', sheet_name='Data')
# Out:
# c:\miniconda\envs\Python_update\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data_4 = pd.read_excel('PMana/PManaFishTiahura.xlsx')

# %%
# create a joint list all of the species
joint_list = list(set(data_1['Species']).union(set(data_2['Species'])).union(set(data_3['Species'])).union(set(data_4['Species'])))

# %%
joint_list
# Out:
# ['Chanos chanos',
#  'Cheilio inermis',
#  'Synodus dermatogenys',
#  'Eviota sp',
#  'Chromis vanderbilti',
#  'Pseudocheilinus tetrataenia',
#  'Canthigaster janthinoptera',
#  'Fusigobius neophytus',
#  'Cantherhines dumerilii',
#  'Chaetodon citrinellus',
#  'Pseudanthias mooreanus',
#  'Rhinecanthus lunula',
#  'Diodon hystrix',
#  'Naso vlamingii',
#  'Aprion virescens',
#  'Gymnosarda unicolor',
#  'Heniochus acuminatus',
#  'Abudefduf septemfasciatus',
#  'Coris aygula',
#  'Acanthurus nigrofuscus',
#  'Parupeneus insularis',
#  'Acanthurus mata',
#  'Chaetodon pelewensis',
#  'Cirrhitichthys oxycephalus',
#  'Seriola rivoliana',
#  'Gnatholepis anjerensis',
#  'Scarus schlegeli',
#  'Parupeneus cyclostomus',
#  'Centropyge flavicauda',
#  'Canthigaster amboinensis',
#  'Pseudojuloides atavai',
#  'Acanthurus nigricans',
#  'Parapercis millepunctata',
#  'Ctenochaetus flavicauda',
#  'Zebrasoma scopas',
#  'Hyporhamphus affinis',
#  'Cirrhilabrus exquisitus',
# ...

# %%
# create a dictionary with the species as keys and the trophic groups as values
trophic_groups = {}
trophic_groups[0] = 'O'
trophic_groups[1] = 'C'
trophic_groups[2] = 'C'
trophic_groups[3] = 'C'
trophic_groups[4] = 'O'
trophic_groups[5] = 'C'
trophic_groups[6] = 'O'
trophic_groups[7] = 'O'
trophic_groups[8] = 'Co'
trophic_groups[9] = 'Co'
trophic_groups[10] = 'C'
trophic_groups[11] = 'O'
trophic_groups[12] = 'O'
trophic_groups[13] = 'O'
trophic_groups[14] = 'C'
trophic_groups[15] = 'C'
trophic_groups[16] = 'P'
trophic_groups[17] = 'O'
trophic_groups[18] = 'O'
trophic_groups[19] = 'H'
trophic_groups[20] = 'C'
trophic_groups[21] = 'O'
trophic_groups[22] = 'Co'
trophic_groups[23] = 'C'
trophic_groups[24] = 'C'
trophic_groups[25] = 'O'
trophic_groups[26] = 'O'
trophic_groups[27] = 'C'
trophic_groups[28] = 'O'
trophic_groups[29] = 'C'
trophic_groups[30] = 'P'
trophic_groups[31] = 'H'
trophic_groups[32] = 'C'
trophic_groups[33] = 'H'
trophic_groups[34] = 'H'
trophic_groups[35] = 'P'
trophic_groups[36] = 'C'
trophic_groups[37] = '0'
trophic_groups[38] = 'O'
trophic_groups[39] = 'C'
trophic_groups[40] = 'C'
trophic_groups[41] = 'H'
trophic_groups[42] = 'C'
trophic_groups[43] = 'Pi'
trophic_groups[44] = 'C'
trophic_groups[45] = 'Pi'
trophic_groups[46] = 'H'
trophic_groups[47] = 'Co'
trophic_groups[48] = 'O'
trophic_groups[269] = 'H'
trophic_groups[270] = 'C'
trophic_groups[271] = 'Pi'
trophic_groups[272] = 'C'
trophic_groups[273] = 'O'
trophic_groups[274] = 'C'
trophic_groups[275] = 'P'
trophic_groups[276] = 'H'
trophic_groups[277] = 'O'
trophic_groups[278] = 'C'
trophic_groups[279] = 'H'
trophic_groups[280] = 'C'
trophic_groups[281] = 'H'
trophic_groups[282] = 'Pi'
trophic_groups[283] = 'O'
trophic_groups[284] = 'O'
trophic_groups[285] = 'C'
trophic_groups[286] = 'C'
trophic_groups[287] = 'C'
trophic_groups[288] = 'O'
trophic_groups[289] = 'H'
trophic_groups[290] = 'C'
trophic_groups[291] = 'H'
trophic_groups[292] = 'C'
trophic_groups[293] = 'O'
trophic_groups[294] = 'C'
trophic_groups[295] = 'C'
trophic_groups[296] = 'Pi'
trophic_groups[297] = 'H'
trophic_groups[298] = 'C'
trophic_groups[299] = 'H'
trophic_groups[300] = 'C'
trophic_groups[301] = 'O'
trophic_groups[302] = 'O'
trophic_groups[303] = 'C'
trophic_groups[304] = 'H'
trophic_groups[305] = 'Pi'
trophic_groups[306] = 'H'
trophic_groups[307] = 'O'
trophic_groups[308] = 'H'
trophic_groups[309] = 'O'
trophic_groups[310] = 'C'
trophic_groups[311] = 'C'
trophic_groups[312] = 'O'
trophic_groups[313] = 'C'
trophic_groups[314] = 'H'
trophic_groups[315] = 'C'
trophic_groups[316] = 'C'
trophic_groups[317] = 'H'
trophic_groups[318] = 'C'
trophic_groups[319] = 'O'
trophic_groups[320] = 'C'
trophic_groups[321] = 'C'
trophic_groups[322] = 'C'
trophic_groups[323] = 'H'
trophic_groups[324] = 'O'
trophic_groups[325] = 'Pi'
trophic_groups[326] = 'Co'
trophic_groups[327] = 'P'
trophic_groups[328] = 'C'
trophic_groups[329] = 'C'
trophic_groups[330] = 'H'
trophic_groups[331] = 'O'
trophic_groups[332] = 'Co'
trophic_groups[333] = 'C'
trophic_groups[334] = 'C'
trophic_groups[335] = 'H'
trophic_groups[336] = 'O'
trophic_groups[337] = 'H'
trophic_groups[338] = 'H'
trophic_groups[339] = 'Co'
trophic_groups[340] = 'C'
trophic_groups[341] = 'C'
trophic_groups[342] = 'C'
trophic_groups[343] = 'C'
trophic_groups[344] = 'C'
trophic_groups[345] = 'P'
trophic_groups[346] = 'C'
trophic_groups[347] = 'H'
trophic_groups[348] = 'O'
trophic_groups[349] = 'O'
trophic_groups[350] = 'Co'
trophic_groups[351] = 'P'
trophic_groups[352] = 'C'
trophic_groups[353] = 'C'
trophic_groups[354] = 'C'
trophic_groups[355] = 'C'

# %%
# change keys to species names
trophic_groups = dict(zip(joint_list, trophic_groups.values()))

# %%
# export dictionary to csv
import csv
with open('trophic_groups.csv', 'w') as f:
    for key in trophic_groups.keys():
        f.write("%s,%s\n"%(key,trophic_groups[key]))

# %%
dict_substrate = {}
dict_substrate['A'] = 'Algae'
dict_substrate['B'] = 'Others'
dict_substrate['C'] = 'Live Coral'
dict_substrate['D'] = 'Pavement'
dict_substrate['O'] = 'Others'
dict_substrate['P'] = 'Calcified Algae'
dict_substrate['M'] = 'Others'
dict_substrate['R'] = 'Rubble'
dict_substrate['S'] = 'Sand'
dict_substrate['T'] = 'Turf'
dict_substrate['?'] = 'Others'
